# %% [markdown]
# <a href="https://colab.research.google.com/github/apusarkar/GP-Regression/blob/master/Shap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import xgboost
import shap

# train an XGBoost model
X, y = shap.datasets.california()
model = xgboost.XGBRegressor().fit(X, y)

# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-c69054f0be31> in <cell line: 5>()
#       3
#       4 # train an XGBoost model
# ----> 5 X, y = shap.datasets.california()
#       6 model = xgboost.XGBRegressor().fit(X, y)
#       7
#
# /usr/local/lib/python3.10/dist-packages/shap/datasets.py in california(display, n_points)
#      35 def california(display=False, n_points=None):
#      36     """Return the california housing data in a nice package."""
# ---> 37     d = sklearn.datasets.fetch_california_housing()
#      38     df = pd.DataFrame(data=d.data, columns=d.feature_names)
#      39     target = d.target
#
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_california_housing.py in fetch_california_housing(data_home, download_if_missing, return_X_y, as_frame)
#     136         )
#     137
# ...

# %%
# !curl -I https://ndownloader.figshare.com/files/5976036
# Out:
# HTTP/2 403
# server: awselb/2.0
# date: Fri, 26 Apr 2024 17:35:20 GMT
# content-type: text/html
# content-length: 118

# %%
import pandas as pd


df = pd.read_csv("FrenchJapanML1.csv")

X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
y
# Out:
# 0       41
# 1       52
# 2       45
# 3       30
# 4       49
#       ...
# 230     77
# 231    104
# 232    114
# 233    126
# 234    131
# Name: DeltaT, Length: 235, dtype: int64

# %%
model = xgboost.XGBRegressor().fit(X, y)

# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])

# %%
import shap
shap.initjs()
# visualize the first prediction's explanation with a force plot
shap.plots.force(shap_values[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
import shap
shap.initjs()
# visualize all the training set predictions
shap.plots.force(shap_values[:500])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# summarize the effects of all the features
shap.plots.beeswarm(shap_values)

# %%
shap.plots.bar(shap_values)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model = GradientBoostingRegressor().fit(X, y)

# %%
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])

# %%
shap.plots.beeswarm(shap_values)
